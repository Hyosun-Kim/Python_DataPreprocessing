# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=1hiCNHNWliU96ZuVD0BnzFxdbaYzNPUtI" width="1200"/>
#
# -  Social Media and Contact
#   - My SNS: [instagram](https://www.instagram.com/ringo_data/?igsh=MTlrdW4xMzZvNTBtdw%3D%3D), [github](https://github.com/Hyosun-Kim)
#   - E-mail: hyosunkim00@gmail.com
#
# ---
# Command + M A = Add a cell above (코드 셀 위에 삽입)
# Command + M B = Add a cell below (코드 셀 아래 삽입)
# Command + M D = Delete a cell (셀 지우기)
# Command + M Y = Change cell to code (코드 셀로 변경)
# Command + M M = Change cell to markdown (마크다운 셀로 변경)
# Command + M Z = Undo (실행 취소)
# <!-- -->
#
# ---

# %% [markdown]
# # Dictionary
#
# ```python
# my_dict = {
#     'key1': 'value1',
#     'key2': 'value2',
#     'key3': 'value3'
# }
# ```

# %%
# value 에 list 활용
dict01 = {
    'col01' : [1,2,3,4],
    'col02' : [10,20,30,40],
    'col03' : [100,200,300,400]
}
dict01
# Out:
# {'col01': [1, 2, 3, 4],
#  'col02': [10, 20, 30, 40],
#  'col03': [100, 200, 300, 400]}

# %%
# DataFrame 으로 변경
import pandas as pd
df = pd.DataFrame(dict01)

# %%
df
# Out:
#    col01  col02  col03
# 0      1     10    100
# 1      2     20    200
# 2      3     30    300
# 3      4     40    400

# %% [markdown]
# # DataFrame 조사

# %% [markdown]
# - head(): 처음 5줄 보여줌.
# - tail(): 마지막 5줄 보여줌.
# - info(): 열 정보, 데이터 타입 요약.
# - describe(): 숫자형 열 통계 요약.
#
# 데이터 프레임에 대한 요약된 정보들을 볼 수 있음.

# %%
# seaborn 으로 데이터 가져오기
# seaborn 이라는 라이브러리에 저장되어 있는 데이터를 가져오기(드라이브에 저장되어있는 것이 아닌)
# https://github.com/mwaskom/seaborn-data
import seaborn as sns
sns.load_dataset('attention')
# Out:
#     Unnamed: 0  subject attention  solutions  score
# 0            0        1   divided          1    2.0
# 1            1        2   divided          1    3.0
# 2            2        3   divided          1    3.0
# 3            3        4   divided          1    5.0
# 4            4        5   divided          1    4.0
# 5            5        6   divided          1    5.0
# 6            6        7   divided          1    5.0
# 7            7        8   divided          1    5.0
# 8            8        9   divided          1    2.0
# 9            9       10   divided          1    6.0
# 10          10       11   focused          1    6.0
# 11          11       12   focused          1    8.0
# 12          12       13   focused          1    6.0
# 13          13       14   focused          1    8.0
# 14          14       15   focused          1    8.0
# 15          15       16   focused          1    6.0
# 16          16       17   focused          1    7.0
# ...

# %%
import seaborn as sns
df_iris = sns.load_dataset('iris')

# %%
df_iris.head(8)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa

# %%
df_iris.tail(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
df_iris.info()
#Dtype data type이라고 생각하면 될 것 같고, object는 문자열 이라고 이해하면 됨
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df_iris.describe()
#std 표준편차 분산이 넓게 분포할 수록 큰 수치
#상위 25프로의 record 50 75 ...
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# # Exercise

# %% [markdown]
# 1. titanic 데이터를 sns로 불러오고 상위 25% age 를 찾으시오

# %%
import seaborn as sns
df_titanic = sns.load_dataset('titanic').describe()
#sns.load_dataset('titanic').describe 괄호 안치고 이렇게 했을 때 또 다르게 나왔었음
#어떤 건지는 나도 잘 모르겠음

# %%
df_titanic
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# ---
# <img src="https://drive.google.com/uc?export=view&id=1hiCNHNWliU96ZuVD0BnzFxdbaYzNPUtI" width="1200"/>
