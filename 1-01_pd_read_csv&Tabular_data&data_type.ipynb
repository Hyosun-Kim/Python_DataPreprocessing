# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=1hiCNHNWliU96ZuVD0BnzFxdbaYzNPUtI" width="1200"/>
#
# -  Social Media and Contact
#   - My SNS: [instagram](https://www.instagram.com/ringo_data/?igsh=MTlrdW4xMzZvNTBtdw%3D%3D), [github](https://github.com/Hyosun-Kim)
#   - E-mail: hyosunkim00@gmail.com
#
# ---
# Command + M A = Add a cell above (코드 셀 위에 삽입)
# Command + M B = Add a cell below (코드 셀 아래 삽입)
# Command + M D = Delete a cell (셀 지우기)
# Command + M Y = Change cell to code (코드 셀로 변경)
# Command + M M = Change cell to markdown (마크다운 셀로 변경)
# Command + M Z = Undo (실행 취소)
# <!-- -->
#
# ---

# %% [markdown]
# ## How to connect to the Google Drive in Colab
#
# > [NOTION](https://www.notion.so/Connect-with-Google-Drive-46abe50d2758444d8a5dca59f0176b84?pvs=4)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # pd.read_csv(): Load the csv data
# ```python
# import pandas as pd
# df = pd.read_csv('path/file.csv')
# ```
# We are gonna import the pandas as name of the "pd" and bring the file through "read_csv".

# %% [markdown]
# ## pd.read_csv

# %%
# how to load iris
# Right-clich the iris file and copy path(경로복사)
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Colab(python+DA)/iris.csv의 사본')

# %%
# what's the type of df?
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
type(df)
#이 데이터 셋은 데이터 프레임으로 들어와있는 걸 알 수 있음.
#데이터 셋을 불러오면 자동으로 데이터프레임 형태로 들어옴.
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ###실무에서 사용하는 99퍼의 데이터 분석할 때 쓰는 파일은 csv 파일이다.
# ####comma seperated value = csv

# %% [markdown]
# # Tabular Data 와 Data type

# %% [markdown]
# ## Tabular Data

# %% [markdown]
# <img src="https://i.ibb.co/0BY3syD/Tabular-Data-explain-1.png" width="500"/>
#
#
# - 행 (Row): 데이터 테이블에서 가로 방향의 데이터 집합. 하나의 행은 특정 `레코드`.
#
# - 열 (Column): 데이터 테이블에서 세로 방향의 데이터 집합. 하나의 열은 특정 `속성`.
#
# - 값 (Value): `행과 열이 교차`하는 지점에 위치한 개별 데이터.
#
# - 인덱스 (Index): `행을 구별`하는 데 사용되는 고유한 식별자.

# %%
#  .shape: 행, 열 수 표시.
#  .columns: 열 이름 나열.
#  .values: 데이터를 배열로 반환.
#  .index: 행 인덱스 반환.

# %%
df.shape
#row가 150개 colum이 6개 있다는 뜻
# Out:
# (150, 6)

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.values
# Out:
# array([[1, 5.1, 3.5, 1.4, 0.2, 'Iris-setosa'],
#        [2, 4.9, 3.0, 1.4, 0.2, 'Iris-setosa'],
#        [3, 4.7, 3.2, 1.3, 0.2, 'Iris-setosa'],
#        [4, 4.6, 3.1, 1.5, 0.2, 'Iris-setosa'],
#        [5, 5.0, 3.6, 1.4, 0.2, 'Iris-setosa'],
#        [6, 5.4, 3.9, 1.7, 0.4, 'Iris-setosa'],
#        [7, 4.6, 3.4, 1.4, 0.3, 'Iris-setosa'],
#        [8, 5.0, 3.4, 1.5, 0.2, 'Iris-setosa'],
#        [9, 4.4, 2.9, 1.4, 0.2, 'Iris-setosa'],
#        [10, 4.9, 3.1, 1.5, 0.1, 'Iris-setosa'],
#        [11, 5.4, 3.7, 1.5, 0.2, 'Iris-setosa'],
#        [12, 4.8, 3.4, 1.6, 0.2, 'Iris-setosa'],
#        [13, 4.8, 3.0, 1.4, 0.1, 'Iris-setosa'],
#        [14, 4.3, 3.0, 1.1, 0.1, 'Iris-setosa'],
#        [15, 5.8, 4.0, 1.2, 0.2, 'Iris-setosa'],
#        [16, 5.7, 4.4, 1.5, 0.4, 'Iris-setosa'],
#        [17, 5.4, 3.9, 1.3, 0.4, 'Iris-setosa'],
#        [18, 5.1, 3.5, 1.4, 0.3, 'Iris-setosa'],
#        [19, 5.7, 3.8, 1.7, 0.3, 'Iris-setosa'],
#        [20, 5.1, 3.8, 1.5, 0.3, 'Iris-setosa'],
# ...

# %%
df.index
#0부터 150까지 1씩 올라가면서 있다는 뜻
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %% [markdown]
# ## Data Type

# %% [markdown]
# 1. **Categorical Data (범주형 데이터):** 제한된 수의 `범주`로 나눌 수 있는 데이터. 예시로는 성별, 혈액형, 학년이 있음
#
# 2. **Numeric Data (수치 데이터):** 수치로 표현되며 `계산이 가능`한 데이터.
#
#     - **Binary Data (이진 데이터):** `'0'과 '1'로만` 구성된 데이터. 예시로는 합격 여부, 물품 구매 여부 등이 있음, 이는 경우에 따라 범주형 데이터로도 분류.
#     - **Ratio Data (비율 데이터):** 값들 사이의 `비율 비교`가 가능한 데이터. 예시로는 키, 몸무게, 가격

# %%
# realistic_binary_data.csv

# %% [markdown]
# # Exercise
# - gg

# %% [markdown]
# 1. pandas 라이브러리를 활용하여 titanic.csv 파일을 불러오세요

# %%
import pandas as pd
pd.read_csv('/content/drive/MyDrive/Colab(python+DA)/titanic.csv의 사본')
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %% [markdown]
# ---
#
# <img src="https://drive.google.com/uc?export=view&id=1hiCNHNWliU96ZuVD0BnzFxdbaYzNPUtI" width="1200"/>
